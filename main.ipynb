# %% [markdown]
# URL untuk dashboard visualisasi = https://public.tableau.com/app/profile/ilham.andrika/viz/Telco_Customer_Churn_Analysis_17549756311740/Dashboard1

# %% [markdown]
# <h2><b>I. Introduction</b></h2>

# %% [markdown]
# Customer Churn Analysis and Insights for a Telecommunication Company
#
# Nama  : Ilham Nauval Andrika
#
# Menganalisis pola customer churn pada perusahaan telekomunikasi dengan mengidentifikasi faktor demografis, penggunaan layanan, dan informasi akun yang memengaruhi tingkat retensi pelanggan. Insight yang dihasilkan ditujukan untuk mendukung strategi berbasis data dalam menurunkan churn rate dan meningkatkan loyalitas pelanggan.

# %% [markdown]
# <h2><b>II. Problem Statement and Dataset Description</b></h2>

# %% [markdown]
# <h3>1. Defining the Problem Statements</h3>
# A. Problem Statement:
#
# Sebuah perusahaan telekomunikasi ingin memahami faktor-faktor yang memengaruhi keputusan pelanggan untuk berhenti berlangganan (churn). Tingkat churn yang tinggi dapat mengurangi pendapatan dan menghambat pertumbuhan perusahaan. Namun, perusahaan belum memiliki wawasan yang jelas mengenai profil pelanggan yang paling berisiko, layanan yang memengaruhi keputusan berhenti, serta strategi retensi yang tepat untuk mengurangi tingkat churn.
#
# B. SMART:
#
# Specific: Menganalisis data pelanggan perusahaan telekomunikasi untuk mengidentifikasi pola, tren, dan faktor utama yang memengaruhi customer churn, serta memberikan rekomendasi berbasis data guna meningkatkan retensi pelanggan.
#
# Measurable: Menghasilkan insight yang terukur seperti persentase pelanggan berisiko, layanan yang paling berpengaruh, dan rekomendasi strategi retensi, dengan target penurunan churn rate sebesar 5-10% dalam periode tertentu.
#
# Achievable: Dengan menggunakan dataset Telco Customer Churn yang berisi informasi demografis, jenis layanan, dan status langganan, analisis dapat dilakukan secara komprehensif untuk mendukung pencapaian tujuan.
#
# Relevant: Mengurangi tingkat customer churn sangat penting bagi keberlanjutan bisnis telekomunikasi karena biaya mendapatkan pelanggan baru jauh lebih tinggi dibanding mempertahankan pelanggan lama.
#
# Time-Bound: Target penurunan churn rate dapat diimplementasikan dan dievaluasi dalam 6 bulan ke depan melalui penerapan strategi retensi yang direkomendasikan.
#
# C. Objective:
#
# Menganalisis pola customer churn pada perusahaan telekomunikasi menggunakan data pelanggan untuk mendapatkan insight dan rekomendasi strategi retensi, sehingga dapat menurunkan tingkat churn dan meningkatkan loyalitas pelanggan dalam 6 bulan ke depan.

# %% [markdown]
# <h3>2. Breaking Down the Problem</h3>
#
# A. Main problem:
#
# Mengidentifikasi faktor-faktor utama yang memengaruhi keputusan pelanggan untuk berhenti berlangganan dan memberikan rekomendasi strategi retensi berbasis data.
#
# B. Menggunakan 5w+1h:
#
# 1. Faktor layanan apa yang paling berpengaruh terhadap churn?
# 2. Segmen pelanggan mana yang paling sering churn berdasarkan demografi?
# 3. Kapan churn paling banyak terjadi berdasarkan lama berlangganan?
# 4. Apakah biaya berlangganan memengaruhi churn?
# 5. Bagaimana strategi retensi dapat dirancang?
# 6. Apakah jenis kontrak memengaruhi churn secara signifikan?
#
# C. Data Understanding:
#
# 1. Basic Data Information
#
# a. Dataset Description
#
# Dataset ini berisi informasi pelanggan perusahaan telekomunikasi, termasuk data demografis, jenis layanan yang digunakan, lama berlangganan, total biaya, serta status berhenti berlangganan (Churn).
#
# b. Context
#
# Menganalisis perilaku dan karakteristik pelanggan telekomunikasi untuk menemukan faktor-faktor yang memengaruhi customer churn, dengan tujuan meningkatkan strategi retensi pelanggan.
#
# c. Content
#
# Dataset ini berisi 7.043 baris dan 21 kolom, mencakup data demografis (gender, senior citizen, partner, dependents), informasi layanan (phone service, internet service, streaming), lama berlangganan (tenure), biaya bulanan (monthly charges), total biaya (total charges), dan status Churn.
#
# d. Columns
#
# - customerID: <b>ID unik untuk setiap pelanggan.</b>
#
# - gender: <b>Jenis kelamin pelanggan (Male/Female).</b>
#
# - SeniorCitizen: <b>Status pelanggan senior citizen (1 = Ya, 0 = Tidak).</b>
#
# - Partner: <b>Apakah pelanggan memiliki pasangan (Yes/No).</b>
#
# - Dependents: <b>Apakah pelanggan memiliki tanggungan (Yes/No).</b>
#
# - tenure: <b>Lama berlangganan dalam bulan.</b>
#
# - PhoneService: <b>Apakah pelanggan memiliki layanan telepon (Yes/No).</b>
#
# - MultipleLines: <b>Status penggunaan lebih dari satu saluran telepon.</b>
#
# - InternetService: <b>Jenis layanan internet (DSL, Fiber optic, None).</b>
#
# - OnlineSecurity, OnlineBackup, DeviceProtection, TechSupport, StreamingTV, StreamingMovies: <b>Status penggunaan layanan tambahan.</b>
#
# - Contract: <b>Jenis kontrak pelanggan (Month-to-month, One year, Two year).</b>
#
# - PaperlessBilling: <b>Apakah menggunakan tagihan tanpa kertas.</b>
#
# - PaymentMethod: <b>Metode pembayaran yang digunakan.</b>
#
# - MonthlyCharges: <b>Biaya bulanan.</b>
#
# - TotalCharges: <b>Total biaya yang dibayarkan pelanggan.</b>
#
# - Churn: <b>Status apakah pelanggan berhenti berlangganan (Yes/No).</b>
#
# 2. Asal Dataset Information
#
# Dataset yang digunakan berasal dari Kaggle dengan judul Telco Customer Churn oleh Blastchar. Dataset ini diambil dari data pelanggan sebuah perusahaan telekomunikasi yang mencakup informasi profil pelanggan, layanan yang digunakan, dan status churn.
# https://www.kaggle.com/datasets/blastchar/telco-customer-churn

# %% [markdown]
# <h2><b>III. Data Loading</b></h2>

# %%
# Import Library
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# %%
# Load dataset dan membuat copy agar masih tetap memiliki dataset asli
df = pd.read_csv('Telco_Customer_Churn_Dataset.csv')
df_copy = df.copy()

# %%
pd.set_option("display.max.columns", None)

# %% [markdown]
# <h2><b>IV. Data Quick Check & Data Cleaning</b></h2>

# %%
# Melihat gambaran dataset 5 baris awal
df_copy.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
# 3  No phone service             DSL            Yes           No
# 4                No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# ...

# %%
# Melihat gambaran dataset 5 baris terakhir
df_copy.tail()
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  \
# 7038          Yes               Yes             DSL            Yes
# 7039          Yes               Yes     Fiber optic             No
# 7040           No  No phone service             DSL            Yes
# 7041          Yes               Yes     Fiber optic             No
# 7042          Yes                No     Fiber optic            Yes
#
#      OnlineBackup DeviceProtection TechSupport StreamingTV StreamingMovies  \
# 7038           No              Yes         Yes         Yes             Yes
# ...

# %%
# Melihat informasi tentang dataset
df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %% [markdown]
# Berdasarkan infromasi yang diperoleh dapat diketahui bahwa dataset ini memiliki 21 kolom dan 7043 baris data yang terdiri dari 18 tipe data object, 2 tipe data integer dan 1 tipe data float. Namun terdapat 1 kolom object yang seharusnya bertipe float karena kolom tersebut mengindikasikan besaran uang yaitu kolom TotalCharges.

# %%
# Melakukan cek apakah terdapat data yang null / misval
df_copy.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %% [markdown]
# Dapat diketahui melalui pengecekan pertama tidak terdapat misval pada dataset, akan tetapi hal ini memerlukan pengecekan ulang karena bisa saja value dari misval data tersebut bukan berbentuk null, nan ataupun none, karena bisa saja hanya berisi spasi.

# %%
# Melakukan pengecekan untuk kedua kalinya apakah terdapat data yang tidak terdeteksi sebagai misval
for col in df_copy.columns:
    kosong = df_copy[df_copy[col] == ' ']
    if not kosong.empty:
        print(f"Kolom {col} ada {len(kosong)} baris berisi spasi yang tidak terdeteksi sebagai null (misval)")
# Out:
# Kolom TotalCharges ada 11 baris berisi spasi yang tidak terdeteksi sebagai null (misval)

# %% [markdown]
# Berdasarkan hasil dari pengecekan ulang dapat diketahui bahwa terdapat beberapa data yang tidak terindikasi misval karena berisi spasi, oleh karena itu maka langkah selanjutnya adalah mengganti spasi dengan nan menggunakan library numpy.

# %%
# Memastikan bahwa terdapat data yang hanya berisi spasi sehingga menyebabkan tidak terdeteksi saat pengecekan misval
df_copy['TotalCharges'].value_counts()
# Out:
# TotalCharges
#           11
# 20.2      11
# 19.75      9
# 20.05      8
# 19.9       8
#           ..
# 6849.4     1
# 692.35     1
# 130.15     1
# 3211.9     1
# 6844.5     1
# Name: count, Length: 6531, dtype: int64

# %%
# Melihat beberapa data yang mengindikasikan memiliki spasi
df_copy[df_copy['TotalCharges']==' ']
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 488   4472-LVYGI  Female              0     Yes        Yes       0
# 753   3115-CZMZD    Male              0      No        Yes       0
# 936   5709-LVOEQ  Female              0     Yes        Yes       0
# 1082  4367-NUYAO    Male              0     Yes        Yes       0
# 1340  1371-DWPAZ  Female              0     Yes        Yes       0
# 3331  7644-OMVMY    Male              0     Yes        Yes       0
# 3826  3213-VVOLG    Male              0     Yes        Yes       0
# 4380  2520-SGTTA  Female              0     Yes        Yes       0
# 5218  2923-ARZLG    Male              0     Yes        Yes       0
# 6670  4075-WKNIU  Female              0     Yes        Yes       0
# 6754  2775-SEFEE    Male              0      No        Yes       0
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  \
# 488            No  No phone service             DSL                  Yes
# ...

# %%
# Merubah value data misval yang tidak teridentifikasi
df_copy['TotalCharges'] = df_copy['TotalCharges'].replace(' ', np.nan)

# %%
# Cek row data misval 
df_copy[df_copy['TotalCharges'].isna()]
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 488   4472-LVYGI  Female              0     Yes        Yes       0
# 753   3115-CZMZD    Male              0      No        Yes       0
# 936   5709-LVOEQ  Female              0     Yes        Yes       0
# 1082  4367-NUYAO    Male              0     Yes        Yes       0
# 1340  1371-DWPAZ  Female              0     Yes        Yes       0
# 3331  7644-OMVMY    Male              0     Yes        Yes       0
# 3826  3213-VVOLG    Male              0     Yes        Yes       0
# 4380  2520-SGTTA  Female              0     Yes        Yes       0
# 5218  2923-ARZLG    Male              0     Yes        Yes       0
# 6670  4075-WKNIU  Female              0     Yes        Yes       0
# 6754  2775-SEFEE    Male              0      No        Yes       0
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  \
# 488            No  No phone service             DSL                  Yes
# ...

# %% [markdown]
# Dapat diketahui bahwa data yang tidak terindikasi misval karena spasi sudah berhasil dirubah isinya menjadi NaN sehingga sudah bisa terdeteksi sebagai data misval.

# %%
# Check jumlah data misval untuk memastikan setelah di replace
df_copy.isnull().sum()
# Out:
# customerID           0
# gender               0
# SeniorCitizen        0
# Partner              0
# Dependents           0
# tenure               0
# PhoneService         0
# MultipleLines        0
# InternetService      0
# OnlineSecurity       0
# OnlineBackup         0
# DeviceProtection     0
# TechSupport          0
# StreamingTV          0
# StreamingMovies      0
# Contract             0
# PaperlessBilling     0
# PaymentMethod        0
# MonthlyCharges       0
# TotalCharges        11
# Churn                0
# dtype: int64

# %% [markdown]
# Kolom TotalCharges yang semestinya bertipe float awalnya tidak dapat dikonversi karena adanya data yang tidak terdeteksi sebagai missing value. Setelah dilakukan deteksi dan penanganan nilai hilang pada kolom tersebut, konversi tipe data menjadi float dapat dilakukan.

# %%
# Melakukan konversi tipe data dari object menjadi float
df_copy['TotalCharges'] = df_copy['TotalCharges'].astype(float)

# %%
# Check apakah kolom TotalCharges berhasil diubah ke tipe data float
df_copy.dtypes
# Out:
# customerID           object
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges        float64
# Churn                object
# dtype: object

# %% [markdown]
# Dapat diketahui bahwa kolom TotalCharges telah berhasil dikonversi menjadi tipe data float. Langkah berikutnya adalah menghitung persentase missing value pada kolom tersebut dengan ambang batas (threshold) 5%.

# %%
# Check berapa persen besar misval pada kolom TotalCharges
missing_percent = df_copy['TotalCharges'].isna().mean() * 100
print(f"Persentase missing di TotalCharges: {missing_percent:.2f}%")
# Out:
# Persentase missing di TotalCharges: 0.16%

# %% [markdown]
# Dapat diketahui bahwa hasil perhitungan menunjukkan persentase missing value sebesar 0,16% (11 data). Karena persentase ini jauh di bawah ambang batas 5%, diputuskan untuk menghapus data yang hilang tersebut agar tidak memengaruhi analisis selanjutnya.

# %%
# Melakukan penghapusan row data misval
df_copy_cleaned = df_copy.dropna()

# %%
# Check apakah berhasil menghapus misval
df_copy_cleaned.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
# Check besaran dataset setelah menghapus misval
df_copy_cleaned.shape
# Out:
# (7032, 21)

# %% [markdown]
# Langkah selanjutnya adalah memeriksa apakah terdapat data duplikat pada dataset.

# %%
# Check data duplikat
df_copy_cleaned.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Dapat diketahui bahwa pemeriksaan menunjukkan dataset bebas dari data duplikat.

# %%
# Melakukan quick check analisa data berdasarkan informasi deskriptif 
df_copy_cleaned.describe(include='all')
# Out:
#         customerID gender  SeniorCitizen Partner Dependents       tenure  \
# count         7032   7032    7032.000000    7032       7032  7032.000000
# unique        7032      2            NaN       2          2          NaN
# top     7590-VHVEG   Male            NaN      No         No          NaN
# freq             1   3549            NaN    3639       4933          NaN
# mean           NaN    NaN       0.162400     NaN        NaN    32.421786
# std            NaN    NaN       0.368844     NaN        NaN    24.545260
# min            NaN    NaN       0.000000     NaN        NaN     1.000000
# 25%            NaN    NaN       0.000000     NaN        NaN     9.000000
# 50%            NaN    NaN       0.000000     NaN        NaN    29.000000
# 75%            NaN    NaN       0.000000     NaN        NaN    55.000000
# max            NaN    NaN       1.000000     NaN        NaN    72.000000
#
#        PhoneService MultipleLines InternetService OnlineSecurity OnlineBackup  \
# ...

# %% [markdown]
# Berdasarkan hasil informasi deskriptif diatas setelah proses pembersihan data, dapat dilihat bahwa dataset Telco Customer Churn berisi 7.032 baris dengan data yang sudah bersih dari nilai hilang maupun duplikat. Kolom numerik seperti SeniorCitizen menunjukkan bahwa hanya sekitar 16% pelanggan yang termasuk kategori senior, sementara sisanya adalah non-senior. Kolom tenure memiliki rata-rata masa berlangganan sekitar 32 bulan, dengan variasi yang cukup besar (standar deviasi 24,54 bulan), serta rentang dari pelanggan baru dengan masa langganan 1 bulan hingga pelanggan lama dengan masa langganan maksimal 72 bulan.
#
# Pada variabel MonthlyCharges, rata-rata biaya bulanan yang dibayarkan pelanggan adalah sekitar USD 64,80, dengan biaya terendah USD 18,25 dan tertinggi USD 118,75. Hal ini menunjukkan adanya perbedaan signifikan pada jenis paket layanan yang diambil pelanggan. Sementara itu, TotalCharges menunjukkan total pengeluaran pelanggan selama berlangganan, dengan rata-rata USD 2.283 dan variasi yang cukup tinggi (standar deviasi USD 2.266), yang sejalan dengan variasi pada lama berlangganan.
#
# Dari kolom kategorikal, terlihat bahwa proporsi pelanggan laki-laki dan perempuan relatif seimbang. Sebagian besar pelanggan tidak memiliki pasangan (Partner = No) dan tidak memiliki tanggungan (Dependents = No). Layanan InternetService paling banyak digunakan adalah Fiber optic, namun menariknya layanan tambahan seperti OnlineSecurity, OnlineBackup, dan TechSupport didominasi oleh jawaban No, yang dapat mengindikasikan potensi peluang untuk upselling. Selain itu, mayoritas pelanggan memiliki kontrak bulanan (Month-to-month) dan menggunakan metode pembayaran Electronic check, yang menurut penelitian churn biasanya lebih rawan terhadap perpindahan layanan dibanding kontrak jangka panjang.
#
# Terakhir, variabel Churn memperlihatkan bahwa pelanggan yang tidak melakukan churn lebih dominan dibandingkan yang churn, yang berarti data ini tidak seimbang (imbalanced dataset).

# %% [markdown]
# <h2><b>V. Exploration and Analysis</b></h2>

# %% [markdown]
# <b>1. Faktor layanan apa yang paling berpengaruh terhadap churn?<b>

# %%
layanan_churn = df_copy_cleaned.groupby(['Churn'])['InternetService'].value_counts()
layanan_churn
# Out:
# Churn  InternetService
# No     DSL                1957
#        Fiber optic        1799
#        No                 1407
# Yes    Fiber optic        1297
#        DSL                 459
#        No                  113
# Name: count, dtype: int64

# %%
plt.figure(figsize=(6,4))
sns.countplot(x='InternetService', hue='Churn', data=df_copy_cleaned, palette='Set2')
plt.title("Tingkat Churn berdasarkan Jenis Internet")
plt.xlabel("Jenis Internet")
plt.ylabel("Jumlah Pelanggan")
plt.show()

# %% [markdown]
# Berdasarkan visualisasi tingkat churn berdasarkan jenis layanan internet, terlihat bahwa pelanggan dengan layanan Fiber optic memiliki jumlah churn yang paling tinggi dibandingkan jenis layanan lainnya. Meskipun jumlah pelanggan Fiber optic yang bertahan (Churn = No) cukup besar, selisihnya dengan jumlah pelanggan yang churn relatif kecil jika dibandingkan dengan layanan DSL maupun pelanggan yang tidak menggunakan layanan internet sama sekali.
#
# Pada layanan DSL, jumlah pelanggan yang bertahan jauh lebih besar daripada yang churn, menunjukkan tingkat loyalitas yang lebih baik. Sebaliknya, pada Fiber optic, perbandingan antara pelanggan yang bertahan dan yang churn lebih seimbang, mengindikasikan adanya tingkat churn yang cukup mengkhawatirkan. Untuk kategori “No” internet service, jumlah pelanggan yang churn sangat sedikit, kemungkinan karena mereka tidak terikat pada layanan internet yang dapat menjadi alasan berpindah penyedia.
#
# Hal ini mengisyaratkan bahwa meskipun Fiber optic adalah layanan internet dengan kecepatan tinggi dan banyak digunakan, ada faktor-faktor lain seperti harga, kualitas layanan, atau persaingan yang membuat pelanggan lebih cenderung untuk berhenti berlangganan. Dengan demikian, Fiber optic tampak menjadi segmen yang paling berisiko terhadap churn dan memerlukan perhatian khusus dalam strategi retensi pelanggan.

# %% [markdown]
# <b>2. Segmen pelanggan mana yang paling sering churn berdasarkan demografi?<b>

# %%
segmen_col = ['gender', 'SeniorCitizen', 'Partner', 'Dependents']
for col in df_copy_cleaned[segmen_col]:
    segmen_churn = df_copy_cleaned.groupby(['Churn'])[col].value_counts()
    print(segmen_churn)
    print("--------------------------------")
# Out:
# Churn  gender
# No     Male      2619
#        Female    2544
# Yes    Female     939
#        Male       930
# Name: count, dtype: int64
# --------------------------------
# Churn  SeniorCitizen
# No     0                4497
#        1                 666
# Yes    0                1393
#        1                 476
# Name: count, dtype: int64
# --------------------------------
# Churn  Partner
# No     Yes        2724
#        No         2439
# Yes    No         1200
#        Yes         669
# Name: count, dtype: int64
# --------------------------------
# Churn  Dependents
# No     No            3390
#        Yes           1773
# Yes    No            1543
#        Yes            326
# Name: count, dtype: int64
# --------------------------------

# %%
fig, axes = plt.subplots(2, 2, figsize=(12, 8))

sns.countplot(ax=axes[0,0], x='gender', hue='Churn', data=df_copy_cleaned, palette='Set1')
axes[0,0].set_title("Churn berdasarkan Gender")

sns.countplot(ax=axes[0,1], x='SeniorCitizen', hue='Churn', data=df_copy_cleaned, palette='Set1')
axes[0,1].set_title("Churn berdasarkan Senior Citizen")

sns.countplot(ax=axes[1,0], x='Partner', hue='Churn', data=df_copy_cleaned, palette='Set1')
axes[1,0].set_title("Churn berdasarkan Status Partner")

sns.countplot(ax=axes[1,1], x='Dependents', hue='Churn', data=df_copy_cleaned, palette='Set1')
axes[1,1].set_title("Churn berdasarkan Status Tanggungan")

plt.tight_layout()
plt.show()

# %% [markdown]
# Berdasarkan visualisasi analisis churn dari sisi demografi, terlihat bahwa gender tidak memberikan perbedaan signifikan pada tingkat churn, karena jumlah pelanggan yang berhenti maupun bertahan hampir seimbang antara laki-laki dan perempuan. Namun, status sebagai Senior Citizen tampaknya berpengaruh, di mana proporsi churn pada pelanggan senior lebih tinggi dibandingkan pelanggan non-senior. Hal ini mengindikasikan bahwa pelanggan yang lebih tua mungkin memiliki sensitivitas yang lebih tinggi terhadap harga atau kualitas layanan.
#
# Dari sisi status hubungan, pelanggan yang tidak memiliki pasangan menunjukkan tingkat churn yang lebih tinggi dibandingkan mereka yang memiliki pasangan, yang bisa jadi berkaitan dengan stabilitas finansial atau komitmen penggunaan layanan. Begitu pula, pelanggan yang tidak memiliki tanggungan (Dependents) cenderung lebih banyak melakukan churn dibandingkan yang memiliki tanggungan, yang kemungkinan terkait dengan perbedaan prioritas pengeluaran atau kebutuhan internet di rumah.
#
# Secara keseluruhan, segmen yang paling sering churn adalah pelanggan yang non-senior namun tetap signifikan pada senior, tidak memiliki pasangan, dan tidak memiliki tanggungan, sementara faktor gender tidak memberikan perbedaan mencolok terhadap perilaku churn.

# %% [markdown]
# <b>3. Kapan churn paling banyak terjadi berdasarkan lama berlangganan?<b>

# %%
tenure_churn = df_copy_cleaned.groupby(['Churn'])['tenure'].describe()
tenure_churn
# Out:
#         count       mean        std  min   25%   50%   75%   max
# Churn
# No     5163.0  37.650010  24.076940  1.0  15.0  38.0  61.0  72.0
# Yes    1869.0  17.979133  19.531123  1.0   2.0  10.0  29.0  72.0

# %%
plt.figure(figsize=(10,6))
sns.histplot(data=df_copy_cleaned, x='tenure', hue='Churn', multiple='stack', palette='Paired', binwidth=10)
plt.title("Distribusi Tenure berdasarkan Churn")
plt.xlabel("Tenure (Bulan)")
plt.ylabel("Jumlah Pelanggan")
plt.show()

# %% [markdown]
# Berdasarkan visualisasi analisis distribusi tenure, churn paling banyak terjadi pada pelanggan dengan masa berlangganan yang sangat singkat, khususnya di bawah 10 bulan. Hal ini terlihat dari tingginya jumlah churn pada rentang awal, yang secara visual mendominasi bagian kiri histogram. Rata-rata tenure pelanggan yang churn hanya sekitar 18 bulan, jauh lebih pendek dibandingkan pelanggan yang bertahan, yang rata-ratanya sekitar 38 bulan.
#
# Fenomena ini mengindikasikan bahwa pelanggan yang baru bergabung memiliki risiko churn yang lebih tinggi, kemungkinan karena ekspektasi layanan yang tidak terpenuhi, harga yang dirasa terlalu mahal, atau kurangnya keterikatan dengan produk. Sebaliknya, pelanggan yang telah bertahan dalam jangka panjang cenderung lebih loyal, dengan proporsi churn yang jauh lebih rendah setelah melewati fase awal berlangganan.
#
# Dalam bisnis telekomunikasi, pola seperti ini biasanya menjadi sinyal kuat untuk fokus pada strategi retensi di 6–12 bulan pertama, karena fase ini adalah “zona rawan” kehilangan pelanggan.

# %% [markdown]
# <b>4. Apakah biaya berlangganan memengaruhi churn?<b>

# %%
MCharges_churn = df_copy_cleaned.groupby(['Churn'])['MonthlyCharges'].describe()
MCharges_churn
# Out:
#         count       mean        std    min    25%    50%     75%     max
# Churn
# No     5163.0  61.307408  31.094557  18.25  25.10  64.45  88.475  118.75
# Yes    1869.0  74.441332  24.666053  18.85  56.15  79.65  94.200  118.35

# %%
plt.figure(figsize=(6,4))
sns.boxplot(x='Churn', y='MonthlyCharges', data=df_copy_cleaned, palette='muted', hue='Churn', legend=False)
plt.title("Distribusi Monthly Charges berdasarkan Churn")
plt.show()

# %% [markdown]
# Berdasarkan visualisasi analisis distribusi biaya bulanan terlihat bahwa pelanggan yang churn cenderung memiliki Monthly Charges yang lebih tinggi dibandingkan pelanggan yang bertahan. Rata-rata biaya bulanan pelanggan churn adalah sekitar $74, lebih tinggi daripada pelanggan yang tidak churn yang rata-ratanya sekitar $61. Selain itu, distribusi pada kelompok churn lebih terkonsentrasi di kisaran menengah hingga tinggi (sekitar $60–$95), sedangkan pelanggan yang bertahan lebih bervariasi, dengan banyak yang membayar di kisaran rendah.
#
# Pola ini menunjukkan bahwa biaya bulanan yang tinggi berpotensi menjadi salah satu faktor pendorong churn. Pelanggan dengan tagihan tinggi mungkin merasa beban biaya tidak sebanding dengan nilai atau manfaat layanan yang mereka terima, apalagi jika mereka tidak menggunakan layanan tambahan secara optimal. Di sisi lain, pelanggan dengan biaya rendah cenderung bertahan lebih lama, kemungkinan karena beban finansial yang lebih ringan membuat mereka tidak terdorong untuk mencari alternatif lain.
#
# Informasi ini dapat menjadi dasar untuk menawarkan paket harga yang lebih fleksibel atau diskon loyalitas bagi pelanggan dengan tarif tinggi, terutama jika mereka sudah menunjukkan tanda-tanda risiko churn.

# %% [markdown]
# <b>5. Bagaimana strategi retensi dapat dirancang?<b>

# %%
desc_stats = df_copy_cleaned[['MonthlyCharges', 'tenure']].describe()
print("\nStatistik Deskriptif:\n", desc_stats)
# Out:
# Statistik Deskriptif:
#         MonthlyCharges       tenure
# count     7032.000000  7032.000000
# mean        64.798208    32.421786
# std         30.085974    24.545260
# min         18.250000     1.000000
# 25%         35.587500     9.000000
# 50%         70.350000    29.000000
# 75%         89.862500    55.000000
# max        118.750000    72.000000

# %%
var_col = ['MonthlyCharges', 'tenure']
for col in df_copy_cleaned[var_col]:
    variance = df_copy_cleaned[col].var()
    print(f'Variance of {col} data:', variance)
# Out:
# Variance of MonthlyCharges data: 905.1658245517284
# Variance of tenure data: 602.4697741951791

# %%
Q1 = df_copy_cleaned['MonthlyCharges'].quantile(0.25)
Q3 = df_copy_cleaned['MonthlyCharges'].quantile(0.75)
IQR = Q3 - Q1
outliers = df_copy_cleaned[(df_copy_cleaned['MonthlyCharges'] < (Q1 - 1.5 * IQR)) | (df_copy_cleaned['MonthlyCharges'] > (Q3 + 1.5 * IQR))]
print(f"\nJumlah Outlier MonthlyCharges: {len(outliers)}")
# Out:
# Jumlah Outlier MonthlyCharges: 0

# %% [markdown]
# Berdasarkan analisa statistik deskriptif diatas, strategi retensi bisa diarahkan pada dua kelompok besar pelanggan: mereka yang membayar tinggi dan mereka yang berada di awal masa berlangganan.
#
# Rata-rata biaya bulanan sekitar $64,8 dengan variasi yang cukup besar (variance kurang lebih 905), menunjukkan adanya rentang harga yang luas. Pelanggan dengan Monthly Charges tinggi, khususnya yang berada di kuartil atas (di atas $90), menjadi kelompok yang perlu perhatian khusus karena dari analisis sebelumnya, tarif tinggi berkorelasi dengan tingkat churn yang lebih besar. Strategi untuk mereka bisa berupa program diskon loyalitas, paket bundling yang menambah nilai tanpa menaikkan harga, atau personalisasi layanan agar mereka merasa biaya yang dibayar sepadan.
#
# Sementara itu, rata-rata tenure hanya sekitar 32 bulan dengan distribusi yang lebar (variance ±602), dan kelompok dengan tenure rendah (kurang dari 12 bulan) adalah yang paling rawan churn. Untuk pelanggan baru, retensi dapat difokuskan pada masa-masa awal dengan memberikan pengalaman onboarding yang kuat, penawaran khusus untuk tahun pertama, dan komunikasi yang lebih intensif untuk membangun keterikatan.
#
# Karena data tidak menunjukkan outlier pada biaya bulanan, ini menandakan tarif yang ada relatif konsisten dan penyesuaian harga untuk strategi retensi bisa dilakukan secara terukur tanpa mengganggu struktur harga keseluruhan.
#
# Strategi ini dimaksudkan untuk merangkul pelanggan yang baru supaya betah, dan meyakinkan pelanggan yang lama bahwa biaya yang mereka bayar layak untuk diteruskan sehingga menciptakan keberlanjutan.

# %% [markdown]
# <b>6. Apakah jenis kontrak memengaruhi churn secara signifikan?<b>

# %%
contingency_table = pd.crosstab(df_copy_cleaned['Contract'], df_copy_cleaned['Churn'])
contingency_table
# Out:
# Churn             No   Yes
# Contract
# Month-to-month  2220  1655
# One year        1306   166
# Two year        1637    48

# %% [markdown]
# H0: Tidak terdapat hubungan yang signifikan antara jenis kontrak pelanggan dan status churn (Proporsi churn pada pelanggan Month-to-month, One year, dan Two year adalah sama).
#
# H1: Terdapat hubungan yang signifikan antara jenis kontrak pelanggan dan status churn (proporsi churn berbeda tergantung jenis kontraknya).

# %%
res = stats.chi2_contingency(contingency_table)
print("P-value:",res.pvalue)

if res.pvalue < 0.05:
    print("-> Hasil signifikan: Ada perbedaan proporsi churn antar tipe kontrak.")
else:
    print("-> Tidak signifikan: Tidak ada bukti perbedaan proporsi churn antar tipe kontrak.")
# Out:
# P-value: 7.326182186265472e-257
# -> Hasil signifikan: Ada perbedaan proporsi churn antar tipe kontrak.

# %% [markdown]
# Berdasarkan hasil analisis statsitik inferensial mengenai keterkaitan jenis kontrak dengan churn melalui uji chi-square menunjukkan p-value yang sangat kecil, jauh di bawah ambang (treshold) 0,05. Artinya, kita dapat menolak hipotesis nol dan menyimpulkan bahwa jenis kontrak memang berpengaruh signifikan terhadap churn.
#
# Berdasarkan informasi dari tabel kontingensi, pelanggan dengan kontrak bulan-ke-bulan memiliki proporsi churn yang jauh lebih tinggi (1655 churn dari total 3875 pelanggan, atau sekitar 42,7%) dibandingkan kontrak satu tahun (166 churn dari 1472 pelanggan, sekitar 11,3%) maupun kontrak dua tahun (48 churn dari 1685 pelanggan, sekitar 2,8%).
#
# Secara bisnis, hal ini dapat dikatakan logis karena kontrak jangka panjang biasanya memberikan insentif seperti harga lebih rendah atau bonus tertentu, sekaligus membuat pelanggan “terikat” lebih lama. Sebaliknya, kontrak bulanan memberi fleksibilitas tinggi untuk keluar, sehingga rawan churn.
#
# Strategi retensi yang bisa diarahkan dari temuan ini adalah untuk mengonversi pelanggan kontrak bulanan ke kontrak tahunan atau dua tahunan dengan penawaran menarik, misalnya diskon biaya bulanan atau bundling layanan tambahan gratis di awal periode.

# %% [markdown]
# <h2><b>VI. Conclusion</b></h2>

# %% [markdown]
# Berdasarkan hasil analisis deskriptif, eksploratif, dan inferensial, dapat disimpulkan bahwa tingkat churn pada pelanggan dipengaruhi oleh kombinasi faktor layanan, demografi, durasi berlangganan, biaya bulanan, serta jenis kontrak yang digunakan.
#
# 1. Faktor layanan menunjukkan bahwa pelanggan dengan layanan Fiber optic memiliki tingkat churn tertinggi dibandingkan DSL maupun pelanggan tanpa layanan internet. Hal ini mengindikasikan adanya potensi masalah terkait harga, kualitas layanan, atau kompetisi pada segmen ini.
#
# 2. Segmen demografi yang lebih rentan churn adalah pelanggan Senior Citizen, mereka yang tidak memiliki pasangan, dan yang tidak memiliki tanggungan. Faktor gender tidak menunjukkan perbedaan signifikan.
#
# 3. Durasi berlangganan (tenure) memperlihatkan bahwa churn paling tinggi terjadi pada pelanggan baru, khususnya dalam 10 bulan pertama, yang menjadi periode kritis untuk membangun loyalitas.
#
# 4. Biaya bulanan yang tinggi berkorelasi dengan peningkatan risiko churn, terutama pada kisaran menengah hingga tinggi. Pelanggan dengan tarif lebih rendah cenderung bertahan lebih lama.
#
# 5. Strategi retensi dapat difokuskan pada pelanggan dengan tarif tinggi dan pelanggan baru. Langkah yang dapat dilakukan mencakup diskon loyalitas, bundling layanan bernilai tambah, program onboarding yang efektif, serta komunikasi personal di masa awal berlangganan.
#
# 6. Jenis kontrak berpengaruh signifikan terhadap churn, di mana kontrak bulanan memiliki proporsi churn jauh lebih besar dibandingkan kontrak tahunan atau dua tahunan. Penawaran insentif untuk beralih ke kontrak jangka panjang menjadi strategi penting untuk menurunkan churn.

# %% [markdown]
# Rekomendasi strategi bisnis yang dapat diterapkan perusahaan untuk menurunkan churn antara lain:
#
# 1. Fokus pada pelanggan Fiber optic
#
#     - Melakukan survei kepuasan untuk mengidentifikasi masalah kualitas atau harga.
#
#     - Menawarkan paket upgrade atau bundling yang memberikan nilai tambah tanpa menaikkan harga yang signifikan.
#
# 2. Retensi pelanggan baru (< 12 bulan)
#
#     - Menerapkan program onboarding dengan edukasi layanan dan manfaat yang jelas.
#
#     - Memberikan insentif seperti diskon untuk bulan-bulan awal atau bonus kuota.
#
# 3. Pengelolaan pelanggan berbiaya tinggi
#
#     - Menyediakan opsi paket harga fleksibel atau customized sesuai kebutuhan.
#
#     - Menawarkan potongan harga untuk pelanggan yang menunjukkan tanda-tanda ingin berhenti.
#
# 4. Konversi kontrak bulanan ke jangka panjang
#
#     - Memberikan diskon atau layanan trial untuk kontrak tahunan atau dua tahunan.
#
#     - Menyampaikan keuntungan jangka panjang secara transparan agar pelanggan merasa diuntungkan.
#
# 5. Pendekatan personal pada segmen rentan
#
#     - Pelanggan senior: Menyediakan layanan bantuan teknis yang ramah dan mudah diakses.
#
#     - Pelanggan tanpa pasangan/tanggungan: Memberikan promosi yang relevan dengan kebutuhan individu, bukan keluarga.

# %% [markdown]
# Secara keseluruhan, hasil analisis ini memberikan gambaran jelas mengenai segmen berisiko tinggi dan faktor-faktor kunci yang memengaruhi churn. Dengan mengimplementasikan strategi retensi yang terarah berdasarkan temuan ini, perusahaan dapat meningkatkan loyalitas pelanggan, menurunkan tingkat churn, serta mempertahankan pendapatan jangka panjang.

# %%
# Menyimpan dataset clean ke file csv untuk diolah menjadi Dashboard
df_copy_cleaned.to_csv('dataset_telcoChurn_cleaned.csv', index=False)
